# %%
Pr=Primes()
def hyperbola_enum():
    pointsOnCurveOne=[]
    pointsOnCurveTwo=[]
    userInput = raw_input("Enter any natural number, this will be mapped to the nth prime\n")
    modulus=Pr.unrank(int(userInput))
    twoInverse = 2.inverse_mod(modulus)
    i=1
    for j in range(1,modulus):
        iInverse=i.inverse_mod(modulus)
        xcor=(twoInverse*(i+iInverse))%modulus
        ycor=(twoInverse*(i-iInverse))%modulus
        pointsOnCurveOne.append((xcor,ycor))
        i+=1
    P=point(pointsOnCurveOne)
    show(P)
hyperbola_enum()
# Out:
# Enter any natural number, this will be mapped to the nth prime
# 1250
# Graphics object consisting of 1 graphics primitive
