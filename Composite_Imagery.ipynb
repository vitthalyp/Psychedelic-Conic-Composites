# %%
prime_limit=int(raw_input("How many primes do you require?\n"))
Prim=Primes()
storage=point([0,0],axes=False,color="white")
number=0 
for num in range(1,150):
    number=Prim.unrank(num)
    end=(number-1)/2
    P=point([[i,j]for i in range(-end,end+1) for j in range(-end,end+1) if((i^2+j^2)%number==1)],size=5,rgbcolor=hue((number%256)/256),axes=False)
    storage+=P
show(storage)
# Out:
# How many primes do you require?
# 100
# Graphics object consisting of 150 graphics primitives

# %%
prime_limit=int(raw_input("How many primes do you require?\n"))
Prim=Primes()
storage=point([0,0],axes=False,color="white")
number=0 
for num in range(1,150):
    number=Prim.unrank(num)
    end=(number-1)/2
    P=point([[i,j]for i in range(-end,end+1) for j in range(-end,end+1) if((i^2-j^2)%number==1)],size=5,rgbcolor=hue((number%256)/256),axes=False)
    storage+=P
show(storage)
# Out:
# How many primes do you require?
# 50
# Graphics object consisting of 150 graphics primitives
